# %% [markdown]
# <a href="https://colab.research.google.com/github/iranovianti/DP_Lab/blob/main/PDA%20tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

sys.path.append('/content/drive/MyDrive/DataScience/Plot_func')
import pda

# %%
pda_file = '/content/drive/MyDrive/Lab/HPLC/220516/220516_PC-Tz(UV_20)_65-75(20) 220516_PC-Tz(UV_20)_65-75(20) (PDA).txt'
mydata = pda.PDA(pda_file, name='PC-Tz 100 mM')

# %%
mydata.plot_at_wl(280, 400, 500, 508)

# %%
mydata.plot_at_rt(12.5, 13.5, colors=['blue', 'red'])

# %%
import numpy as np

# %%
np.array([10, 15, 20]) * 10
# Out:
# array([100, 150, 200])

# %%
mydata.detect_peak(wl=280)
# Out:
# detecting peaks from chromatogram at 280 nm
# 3 peaks registered
# peak_1 at 7.07 min
# peak_2 at 12.53 min
# peak_3 at 13.43 min

# %%
mydata.plot_peaks(1, 2, 3, colors=['black', 'blue', 'red'],
                  xlim=(450, 600), ylim=(-100, 5000))

# %%
mydata.info()
# Out:
# PDA name: PC-Tz 100 mM
# Wavelength range: 200.0 - 648.0 nm (113 points)
# Monitored time: 20.28 min
